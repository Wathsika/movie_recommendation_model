# %% [markdown]
# <a href="https://colab.research.google.com/github/Wathsika/movie_recommendation_model/blob/main/evaluate_movie_recommendation_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
